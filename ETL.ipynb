# %% [markdown]
# <h3>Comienzo con el trabajo de ETL sobre mis datasets<h3>

# %% [markdown]
# Importo las librerías a utilizar

# %%
import pandas as pd

# %% [markdown]
# Abro los datasets e imprimo un sample para realizar un análisis exploratorio general de mis datos.
# Además, creo copias auxiliares de mis datasets como backup.

# %%
df_amazon = pd.read_csv("app\\datasets\\amazon_prime_titles.csv",delimiter = ',',encoding = "utf-8")
df_amazonaux = df_amazon.copy()
df_amazon.sample(5)
# Out:
#      show_id     type                                              title  \
# 9662   s9663    Movie                                              River
# 8090   s8091    Movie                            Saturday Marijuana Eyez
# 2301   s2302  TV Show                                         Gracepoint
# 6927   s6928    Movie  Whitey: United States of America v. James J. B...
# 3828   s3829    Movie         Lisa Lampanelli: Back To The Drawing Board
#
#            director                                               cast  \
# 9662     Emily Skye  Mary Cameron Rogers, Alexandra Rose, Rob Marsh...
# 8090  CHILLZ MENTAL  DAKSTON BROWN, RAYMOND B, DONTE CROSS, L Whash...
# 2301            NaN  David Tennant, Anna Gunn, Michael Peña, Virgin...
# 6927  Joe Berlinger                              James J. Bulger,  Jr.
# 3828    Jay Chapman                                    Lisa Lampanelli
#
#      country date_added  release_year rating  duration  \
# 9662     NaN        NaN          2021    16+    93 min
# 8090     NaN        NaN          2017    18+    54 min
# 2301     NaN        NaN          2014    13+  1 Season
# 6927     NaN        NaN          2014      R   107 min
# 3828     NaN        NaN          2015    18+    60 min
#
#                                               listed_in  \
# 9662                   Drama, Science Fiction, Suspense
# 8090   Action, Arts, Entertainment, and Culture, Comedy
# 2301                                    Drama, Suspense
# 6927                              Documentary, Suspense
# 3828  Arts, Entertainment, and Culture, Comedy, Spec...
#
#                                             description
# 9662  River is a grounded Sci-Fi mystery Thriller, t...
# 8090  A sunny afternoon in Compton, Ca gets real hea...
# 2301  When a young boy is found dead on an idyllic b...
# 6927  The true story of Whitey Bulger, inspiration f...
# 3828  Brash, bold and never afraid to go blue, comed...

# %%
df_disney = pd.read_csv("app\\datasets\\disney_plus_titles.csv",delimiter = ',',encoding = "utf-8")
df_disneyaux = df_disney.copy()
df_disney.sample(5)
# Out:
#      show_id     type                                 title       director  \
# 533     s534  TV Show                       Birth of Europe            NaN
# 758     s759    Movie                              Boundin'     Bud Luckey
# 42       s43    Movie  Alvin and the Chipmunks: Chipwrecked  Mike Mitchell
# 772     s773    Movie            Camp Rock 2: The Final Jam      Paul Hoen
# 1173   s1174    Movie                         Sacred Planet       Jon Long
#
#                                                    cast  \
# 533                                       Mark Halliley
# 758                                          Bud Luckey
# 42    Jason Lee, David Cross, Jenny Slate, Justin Lo...
# 772   Demi Lovato, Joe Jonas, Nick Jonas, Kevin Jona...
# 1173  Robert Redford, Arapata McKay, Tsaan Ciqae, Ma...
#
#                               country         date_added  release_year rating  \
# 533                    United Kingdom        May 1, 2020          2014   TV-G
# 758                     United States  November 12, 2019          2004      G
# 42                      United States   November 5, 2021          2011      G
# 772                     United States  November 12, 2019          2010   TV-G
# 1173  Canada, Malaysia, United States  November 12, 2019          2004      G
#
#       duration                              listed_in  \
# 533   1 Season                             Docuseries
# 758      6 min                Animation, Family, Kids
# 42      87 min                  Comedy, Family, Music
# 772    101 min          Coming of Age, Music, Musical
# 1173    47 min  Animals & Nature, Documentary, Family
#
#                                             description
# 533   Birth of Europe reveals the extraordinary stor...
# 758               The musical story of a dancing sheep.
# 42    The Chipmunks and Chipettes get stranded on a ...
# 772   To save Camp Rock, Mitchie challenges Camp Sta...
# 1173  Visit some of the most exotic and beautiful pl...

# %%
df_hulu = pd.read_csv("app\\datasets\\hulu_titles.csv",delimiter = ',',encoding = "utf-8")
df_huluaux = df_hulu.copy()
df_hulu.sample(5)
# Out:
#      show_id     type                  title director  cast         country  \
# 1566   s1567  TV Show  Welcome to Plathville      NaN   NaN   United States
# 1573   s1574  TV Show                 Merlin      NaN   NaN  United Kingdom
# 81       s82    Movie           Chasing Papi      NaN   NaN             NaN
# 1871   s1872  TV Show       Flea Market Flip      NaN   NaN   United States
# 296     s297    Movie                 Solace      NaN   NaN             NaN
#
#              date_added  release_year rating   duration  \
# 1566       July 1, 2020          2019  TV-PG   1 Season
# 1573      June 25, 2020          2008  TV-14  5 Seasons
# 81      October 1, 2021          2003     PG     80 min
# 1871   January 22, 2020          2012   TV-G  4 Seasons
# 296   September 1, 2021          2015      R    102 min
#
#                                   listed_in  \
# 1566                                Reality
# 1573  Drama, International, Science Fiction
# 81                   Comedy, Drama, Romance
# 1871            Family, Lifestyle & Culture
# 296                  Drama, Horror, Mystery
#
#                                             description
# 1566  The Plaths are a strikingly blonde, blue-eyed ...
# 1573  The adventures of the legendary sorcerer as a ...
# 81    A Latino Casanova courts three Hispanic women ...
# 1871  Contestants are given $500 to buy items that t...
# 296   Unable to solve a series of homicides, the FBI...

# %%
df_netflix = pd.read_json("app\\datasets\\netflix_titles.json",orient="records")
df_netflixaux = df_netflix.copy()
df_netflix.sample(5)
# Out:
#      show_id     type                          title  \
# 3046   s3047    Movie  All the Freckles in the World
# 1106   s1107    Movie    Cross: Rise of the Villains
# 7763   s7764  TV Show     Power Rangers Dino Thunder
# 2055   s2056    Movie      Freaks – You're One of Us
# 7368   s7369  TV Show                        Mad Men
#
#                           director  \
# 3046                  Yibrán Asuad
# 1106  Patrick Durham, Paul G. Volk
# 7763                          None
# 2055                  Felix Binder
# 7368                          None
#
#                                                    cast        country  \
# 3046  Hánssel Casillas, Loreto Peralta, Andrea Sutto...         Mexico
# 1106  Brian Austin Green, Vinnie Jones, Lori Heuring...  United States
# 7763  James Napier, Kevin Duhaney, Emma Lahana, Jaso...  United States
# 2055  Cornelia Gröschel, Tim Oliver Schultz, Wotan W...        Germany
# 7368  Jon Hamm, Elisabeth Moss, Vincent Kartheiser, ...  United States
#
#              date_added  release_year rating   duration  \
# 3046    January 3, 2020          2020  TV-14     90 min
# 1106      April 2, 2021          2019      R    100 min
# 7763    January 1, 2016          2004  TV-Y7   1 Season
# 2055  September 2, 2020          2020  TV-MA     93 min
# 7368     March 22, 2015          2014  TV-14  7 Seasons
#
#                                              listed_in  \
# 3046   Comedies, International Movies, Romantic Movies
# 1106                                Action & Adventure
# 7763                                          Kids' TV
# 2055  Dramas, Independent Movies, International Movies
# 7368                                         TV Dramas
#
#                                             description
# 3046  Thirteen-year-old José Miguel is immune to 199...
# 1106  Armed with a mighty ancient amulet, a team of ...
# 7763  Dr. Tommy Oliver returns when his students dis...
# 2055  Tipped by a mysterious tramp, a meek fry cook ...
# 7368  Set in 1960s New York City, this award-winning...

# %% [markdown]
# <h3>Comienzo un análisis general de mis datasets para saber cuántos datos faltantes (None/NaN/null) y datos repetidos se encuentran para luego eliminarlos.<h3>

# %% [markdown]
# Empiezo la limpieza de mi dataset "df_amazon".

# %%
#Elimino las columnas que no me servirán para las consultas indicadas.

df_amazon = df_amazon.drop(columns=["show_id","director","country","date_added","rating","description"])

# %%
#df_amazon.count().sum()
#df_amazon.isnull().sum().sum()

print("El número total de registros es de:",df_amazon.count().sum(),"\nEl número de registros faltantes es de:",df_amazon.isnull().sum().sum())
# Out:
# El número total de registros es de: 56775
# El número de registros faltantes es de: 1233

# %%
#Traigo los valores faltantes por columna
df_amazon.isnull().sum()
# Out:
# type               0
# title              0
# cast            1233
# release_year       0
# duration           0
# listed_in          0
# dtype: int64

# %%
#Reemplazo mis valores nulos por "Sin datos" en lugar de eliminarlos para no perder información valiosa.

df_amazon = df_amazon.fillna("Sin Datos")

# %%
print("El número total de registros en el dataset es de:",df_amazon.count().sum(),"\nEl número de registros faltantes luego del fillna() es de:",df_amazon.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 58008
# El número de registros faltantes luego del fillna() es de: 0

# %%
#Traigo los valores faltantes por columna luego del fillna()
df_amazon.isnull().sum()
# Out:
# type            0
# title           0
# cast            0
# release_year    0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Verifico no tener duplicados en mi columna Titles, ya que es la única que me interesa que no posea valores repetidos.
#(Un director puede estar en más de una película/serie, las categorías de 2 o más películas/series puede coincidir así como el cast, duración etc...)

#df_amazon.title.nunique()

print("El número de títulos individuales que se encuentran en el dataset de Amazon es de:",df_amazon.title.nunique())
# Out:
# El número de títulos individuales que se encuentran en el dataset de Amazon es de: 9668

# %%
#Utilizamos el siguiente método en cada una de las columnas para verificar la presencia de datos anómalos como carácteres especiales, espacios vacíos, números, etc.
#df_amazon.sort_values(by=["columna_a_analizar"],ascending=True).head(20)

#Encontramos que hay valores en cast con nombre "1","1,2,3" por lo que cambiaremos estos valores por Sin Datos
df_amazon.sort_values(by=['cast'],ascending=True).head(36)
# Out:
#          type                                      title  \
# 7217  TV Show            Series before 1C onboarding - 7
# 7239    Movie  Clip: ACT 4 - Title after removing 1C - 2
# 8764  TV Show                           Act 2 - Series 1
# 7238    Movie  Clip: ACT 4 - Title after removing 1C - 5
# 8728  TV Show                           ACT 2 - Series 6
# 8727  TV Show                           Act 5 - Series 1
# 8726  TV Show                           Act 5 - Series 2
# 7245    Movie        ACT 4 - Title after removing 1C - 1
# 6418  TV Show            Series before 1C onboarding - 2
# 6628  TV Show            Series before 1C onboarding - 1
# 8724  TV Show                           Act 6 - Series 2
# 7127    Movie       Act 4 - Title before 1C onboarding 2
# 9462    Movie                      Clip: Act 5 - Title 5
# 7139    Movie                                    Clip: 1
# 8708  TV Show                     Clip: ACT 2 - Series 5
# 8725  TV Show                           Act 6 - Series 1
# 7128    Movie       Act 4 - Title before 1C onboarding 1
# 8501    Movie                            Act 6 - Title 1
# 7258    Movie  Clip: ACT 4 - Title after removing 1C - 4
# 8762  TV Show                           Act 2 - Series 2
# 8761  TV Show                           Act 2 - Series 3
# 8760  TV Show                           Act 2 - Series 4
# 8759  TV Show                           ACT 2 - Series 8
# 8758    Movie                            ACT 2 - TITLE 6
# 7319  TV Show               Clip: ACT 3 Series post 1C 2
# 8757    Movie                            ACT 2 - TITLE 7
# 6930    Movie                    Title Post onboarding 8
# 9463    Movie                      Clip: Act 5 - Title 3
# 8755    Movie                            ACT 2 - TITLE 9
# 8753  TV Show                           ACT 2 - Series 7
# 8752  TV Show                           ACT 2 - Series 9
# 8502    Movie                            Act 5 - Title 1
# 8763  TV Show                          ACT 2 - Series 10
# 8756    Movie                            ACT 2 - TITLE 8
# 6416    Movie             Title before 1C onboarding - 5
# 608   TV Show                          THE IDOLM@STER.KR
#
#                                                    cast  release_year  \
# 7217                                                  1          2021
# 7239                                                  1          2021
# 8764                                                  1          2021
# 7238                                                  1          2021
# 8728                                                  1          2021
# 8727                                                  1          2021
# 8726                                                  1          2021
# 7245                                                  1          2021
# 6418                                                  1          2021
# 6628                                                  1          2021
# 8724                                                  1          2021
# 7127                                                  1          2021
# 9462                                                  1          2021
# 7139                                                  1          2021
# 8708                                                  1          2021
# 8725                                                  1          2021
# 7128                                                  1          2021
# 8501                                                  1          2021
# 7258                                                  1          2021
# 8762                                                  1          2021
# 8761                                                  1          2021
# 8760                                                  1          2021
# 8759                                                  1          2021
# 8758                                                  1          2021
# 7319                                                  1          2021
# 8757                                                  1          2021
# 6930                                                  1          2021
# 9463                                                  1          2021
# 8755                                                  1          2021
# 8753                                                  1          2021
# 8752                                                  1          2021
# 8502                                                  1          2021
# 8763                                                  1          2021
# 8756                                                  1          2021
# 6416                                            1, 2, 3          2021
# 608   10 singers from Real Girls Project, Sung Hoon,...          2017
#
#        duration          listed_in
# 7217   1 Season             Action
# 7239     61 min             Action
# 8764  2 Seasons           TV Shows
# 7238     61 min             Action
# 8728   1 Season           TV Shows
# 8727  3 Seasons             Action
# 8726   1 Season           TV Shows
# 7245     61 min             Action
# 6418  2 Seasons  Action, Animation
# 6628   1 Season           TV Shows
# 8724   1 Season           TV Shows
# 7127     61 min             Action
# 9462     61 min          Animation
# 7139      3 min             Action
# 8708   1 Season           TV Shows
# 8725   1 Season             Action
# 7128     61 min             Action
# 8501     61 min             Action
# 7258     61 min             Comedy
# 8762  2 Seasons             Action
# 8761  2 Seasons           TV Shows
# 8760  2 Seasons             Action
# 8759   1 Season           TV Shows
# 8758     61 min             Action
# 7319   1 Season           TV Shows
# 8757     61 min             Action
# 6930     61 min             Action
# 9463     61 min             Action
# 8755     61 min             Action
# 8753   1 Season           TV Shows
# 8752   1 Season           TV Shows
# 8502     61 min             Action
# 8763   1 Season           TV Shows
# 8756     61 min             Action
# 6416      3 min              Drama
# 608    1 Season           TV Shows

# %%
df_amazon.cast = df_amazon.cast.replace("1","Sin Datos")
df_amazon.cast = df_amazon.cast.replace("1, 2, 3","Sin Datos")
df_amazon.sort_values(by=['cast'],ascending=True).head(36)
# Out:
#          type                                              title  \
# 608   TV Show                                  THE IDOLM@STER.KR
# 2249  TV Show                            Harmony with A R Rahman
# 2893  TV Show                            Celebrity Ghost Stories
# 3793    Movie                               Phantasm: Remastered
# 8527    Movie                                         Thiruvarul
# 8617    Movie                                          Thunaivan
# 6783    Movie                                  Annaiyum Pithavum
# 2408    Movie  Funny Lesson Learn Colors with Cows and Balls ...
# 6162    Movie                                   Deva Rickshawala
# 6491    Movie                                       Flat No. 609
# 5434    Movie                                     Sound of Water
# 7509    Movie                                      Synchronicity
# 5879    Movie                                       Meera Mathur
# 23    TV Show                                       ZeroZeroZero
# 8630    Movie        The End Will Be Spectacular - Ji Bo Azadiyê
# 6482    Movie                                         Maayanadhi
# 5287    Movie                                              Fanaa
# 4564    Movie                                    Raja Hindustani
# 4877    Movie                                     Love Ni Bhavai
# 8348    Movie                                            25 Sets
# 3024    Movie                               Blood, Sand and Gold
# 1852    Movie                                       Line of Duty
# 4404    Movie                                             Wander
# 6430    Movie                                 Spirit of the Game
# 5406  TV Show                                Underbelly: Chopper
# 4073    Movie                                              Dummy
# 5154    Movie                                      Floating City
# 2708    Movie              Daydream Believers: The Monkees Story
# 824     Movie                    T-Rex Ranch Dinosaur Adventures
# 5189  TV Show  Dinosaur Quests with The Park Rangers by T-Rex...
# 4068    Movie                                          Goldstone
# 1535    Movie                                       Mystery Road
# 5487    Movie                        The Curse Of The Blind Dead
# 4046    Movie                                           The Wall
# 6088    Movie                                   Hajar Juni Samma
# 1794    Movie                    Loveyatri - The Journey of Love
#
#                                                    cast  release_year  \
# 608   10 singers from Real Girls Project, Sung Hoon,...          2017
# 2249  A R Rahman, Sajith Vijayan, Bahauddin Dagar, B...          2018
# 2893                                           A. Jones          2011
# 3793  A. Michael Baldwin, Bill Thornbury, Reggie Ban...          1979
# 8527             A. V. M. Rajan, Jaya, Nagesh, Sukumari          1975
# 8617       A. V. M. Rajan, Sowkar Janaki, Nagesh, Sachu          1969
# 6783  A. V. M. Rajan, Vanisri, Sivakumar, Lakshmi, M...          1969
# 2408                                    ABC Kids Studio          2018
# 6162  ABHINAV KUMAR, VERSA RITTU, SHASHI BHUSAN, RAM...          2021
# 6491          ABIR CHATTERJEE, TANUSREE, RUDRANIL GHOSH          2018
# 5434                      ABRAAM PANDEY, JASHPREET KAUR          2021
# 7509  AJ Bowen, Brianne Davis, Michael Ironside, Cha...          2016
# 5879  ALAN KAPOOR, KHUSHI RAJPOOT, ASHWIN KAPOOR, RA...          2021
# 23    ANDREA RISEBOROUGH, HAROLD TORRES, CLAUDIA PIN...          2020
# 8630  ARJÎN BAYSAL, DELÎL PÎRAN, CÎHAN SEVE, SAHÎRE ...          2019
# 6482   Aadukalam Naren, Venba, Abi Saravanan, Appukutty          2020
# 5287  Aamir Khan, Kajol, Rishi Kapoor, Lara Dutta, S...          2006
# 4564  Aamir Khan, Karisma Kapoor, Suresh Oberoi, Joh...          1996
# 4877         Aarohi Patel, Malhar Thakar, Pratik Gandhi          2017
# 8348  Aaron Berg, Jim Gaffigan, Sal Vulcano, Dave At...          2019
# 3024  Aaron Costa Ganis, Monica West, Christopher Re...          2017
# 1852      Aaron Eckhart, Dina Meyer, Giancarlo Esposito          2019
# 4404  Aaron Eckhart, Tommy Lee Jones, Katheryn Winni...          2020
# 6430          Aaron Jakubenko, Kevin Sorbo, Wade Briggs          2016
# 5406  Aaron Jeffery, Todd Lasance, Vince Colosimo, E...          2018
# 4073  Aaron Johnson, Thomas Grant, Emma Catherwood, ...          2008
# 5154                    Aaron Kwok, Josie Ho, Annie Liu          2012
# 2708                                         Aaron Lohr          2000
# 824                                   Aaron Michael, LB          2021
# 5189                                  Aaron Michael, LB          2019
# 4068  Aaron Pederson, Alex Russell, Cheng Pei-Pei, D...          2018
# 1535         Aaron Pederson, Hugo Weaving, Ryan Kwanten          2013
# 5487  Aaron Stielstra, Alice Zanini, Francesca Pelle...          2021
# 4046       Aaron Taylor-Johnson, John Cena, Laith Nakli          2017
# 6088  Aaryan Sigdel, Swastima Khadka, Priyanka Karki...          2019
# 1794  Aayush Sharma, Warina Hussain, Ronit Roy Bose,...          2018
#
#        duration                                          listed_in
# 608    1 Season                                           TV Shows
# 2249   1 Season      Arts, Entertainment, and Culture, Documentary
# 2893  3 Seasons                                           TV Shows
# 3793     89 min                            Horror, Science Fiction
# 8527    138 min                                              Drama
# 8617    155 min                                              Drama
# 6783    154 min                                      Comedy, Drama
# 2408      2 min                                    Animation, Kids
# 6162    127 min                                     Drama, Romance
# 6491    103 min                                             Horror
# 5434    117 min                                            Romance
# 7509    100 min                 Fantasy, Science Fiction, Suspense
# 5879     91 min                                              Drama
# 23     1 Season                                           TV Shows
# 8630    142 min                                      Action, Drama
# 6482    113 min                                            Romance
# 5287    168 min                                            Romance
# 4564    170 min                                     Drama, Romance
# 4877    163 min                                Comedy, Drama, Kids
# 8348     58 min  Arts, Entertainment, and Culture, Comedy, Docu...
# 3024     89 min                          Action, Adventure, Comedy
# 1852     99 min                                  Action, Adventure
# 4404     93 min                        Action, Adventure, Suspense
# 6430     98 min    Drama, Faith and Spirituality, Special Interest
# 5406   1 Season                                              Drama
# 4073     85 min                                              Drama
# 5154    105 min                                     Drama, Romance
# 2708     92 min    Action, Arts, Entertainment, and Culture, Drama
# 824      35 min                                               Kids
# 5189  6 Seasons                                               Kids
# 4068    110 min                                      Action, Drama
# 1535    121 min                            Action, Drama, Suspense
# 5487     88 min                                   Horror, Suspense
# 4046     90 min                  Drama, Military and War, Suspense
# 6088    123 min                                            Romance
# 1794    133 min                     Comedy, International, Romance

# %%
#Imprimimos una sample para darnos una idea de cómo quedó el dataset luego de la limpieza, encontramos valores "Sin Datos" en lugar de Nulls o valores anómalos.
df_amazon.sample(10)
# Out:
#          type                        title  \
# 1305  TV Show  Pinkfong! Outer Space Songs
# 7369    Movie            Valley of Ditches
# 163   TV Show           Wakaalat From Home
# 7632  TV Show               Def Comedy Jam
# 8820    Movie                   Underworld
# 4054    Movie     Netherbeast Incorporated
# 5300    Movie                      Befikre
# 7351    Movie           The Bedroom Window
# 9148    Movie  More Sex and The Single Mom
# 1484    Movie     Night Falls on Manhattan
#
#                                                    cast  release_year  \
# 1305                                          Sin Datos          2021
# 7369  Amanda Todisco, Russell Bradley Fenton, Jeremy...          2017
# 163   Sumeet Vyas, Nidhi Singh, Kubbra Sait, Gopal D...          2020
# 7632  Steve Harvey, Kid Capri, James Hannah, Jack Sh...          1992
# 8820  Denis Leary, Joe Mantegna, Annabella Sciora, L...          1997
# 4054               Steve Burns, Dave Foley, Judd Nelson          2007
# 5300  Ranveer Singh, Vaani Kapoor, Armaan Ralhan, Ju...          2016
# 7351  Steve Guttenberg, Elizabeth McGovern, Isabelle...          1987
# 9148            Gail O'Grady, Grant Show, Chelsea Hobbs          2005
# 1484  Andy Garcia, Lena Olin, Richard Dreyfuss, Ian ...          1997
#
#        duration                                 listed_in
# 1305  2 Seasons                           Animation, Kids
# 7369     80 min                          Horror, Suspense
# 163    1 Season                                    Comedy
# 7632  7 Seasons  Arts, Entertainment, and Culture, Comedy
# 8820     95 min                          Comedy, Suspense
# 4054     89 min                   Comedy, Science Fiction
# 5300    130 min              Comedy, Drama, International
# 7351    113 min                                  Suspense
# 9148     90 min                            Drama, Romance
# 1484    114 min                                     Drama

# %% [markdown]
# Empiezo la limpieza de mi dataset "df_disney".

# %%
df_disney.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
#
#           date_added  release_year rating  duration  \
# 0  November 26, 2021          2016   TV-G    23 min
# 1  November 26, 2021          1988     PG    91 min
# 2  November 26, 2021          2011   TV-G    23 min
# 3  November 26, 2021          2021  TV-PG    41 min
# 4  November 25, 2021          2021    NaN  1 Season
#
#                        listed_in  \
# 0              Animation, Family
# 1                         Comedy
# 2      Animation, Comedy, Family
# 3                        Musical
# 4  Docuseries, Historical, Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %%
#Elimino las columnas que no me servirán para las consultas indicadas.

df_disney = df_disney.drop(columns=["show_id","director","country","date_added","rating","description"])

# %%
#df_disney.count().sum()
#df_disney.isnull().sum().sum()

print("El número total de registros en el dataset es de:",df_disney.count().sum(),"\nEl número de registros faltantes es de:",df_disney.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 8510
# El número de registros faltantes es de: 190

# %%
#Traigo los valores faltantes por columna
df_disney.isnull().sum()
# Out:
# type              0
# title             0
# cast            190
# release_year      0
# duration          0
# listed_in         0
# dtype: int64

# %%
#Reemplazo mis valores nulos por "Sin datos" en lugar de eliminarlos para no perder información valiosa.

df_disney = df_disney.fillna("Sin Datos")

# %%
print("El número total de registros en el dataset es de:",df_disney.count().sum(),"\nEl número de registros faltantes luego del fillna() es de:",df_disney.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 8700
# El número de registros faltantes luego del fillna() es de: 0

# %%
#Traigo los valores faltantes por columna luego del fillna()
df_disney.isnull().sum()
# Out:
# type            0
# title           0
# cast            0
# release_year    0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Verifico no tener duplicados en mi columna Titles, ya que es la única que me interesa que no posea valores repetidos.
#(Un director puede estar en más de una película/serie, las categorías de 2 o más películas/series puede coincidir así como el cast, duración etc...)

#df_disney.title.nunique()

print("El número de títulos individuales que se encuentran en el dataset de Disney es de:",df_disney.title.nunique())
# Out:
# El número de títulos individuales que se encuentran en el dataset de Disney es de: 1450

# %%
#Utilizamos el siguiente método en cada una de las columnas para verificar la presencia de datos anómalos como carácteres especiales, espacios vacíos, números, etc.
#df_disney.sort_values(by=["columna_a_analizar"],ascending=True).head(20)

#Luego de correr el código sobre cada columna, no encontramos valores anómalos.

# %% [markdown]
# Empiezo la limpieza de mi dataset "df_hulu".

# %%
df_hulu.head()
# Out:
#   show_id   type                           title director  cast country  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN   NaN     NaN
# 1      s2  Movie                    Silent Night      NaN   NaN     NaN
# 2      s3  Movie                    The Marksman      NaN   NaN     NaN
# 3      s4  Movie                            Gaia      NaN   NaN     NaN
# 4      s5  Movie                        Settlers      NaN   NaN     NaN
#
#          date_added  release_year rating duration                  listed_in  \
# 0  October 24, 2021          2021  TV-MA      NaN           Comedy, Stand Up
# 1  October 23, 2021          2020    NaN   94 min     Crime, Drama, Thriller
# 2  October 23, 2021          2021  PG-13  108 min           Action, Thriller
# 3  October 22, 2021          2021      R   97 min                     Horror
# 4  October 22, 2021          2021    NaN  104 min  Science Fiction, Thriller
#
#                                          description
# 0  ​Comedian Ricky Velez bares it all with his ho...
# 1  Mark, a low end South London hitman recently r...
# 2  A hardened Arizona rancher tries to protect an...
# 3  A forest ranger and two survivalists with a cu...
# 4  Mankind's earliest settlers on the Martian fro...

# %%
#Elimino las columnas que no me servirán para las consultas indicadas.

df_hulu = df_hulu.drop(columns=["show_id","director","country","date_added","rating","description"])

# %%
#df_hulu.count().sum()
#df_hulu.isnull().sum().sum()

print("El número total de registros en el dataset es de:",df_hulu.count().sum(),"\nEl número de registros faltantes es de:",df_hulu.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 14886
# El número de registros faltantes es de: 3552

# %%
#Traigo los valores faltantes por columna
df_hulu.isnull().sum()
# Out:
# type               0
# title              0
# cast            3073
# release_year       0
# duration         479
# listed_in          0
# dtype: int64

# %%
#Reemplazo mis valores nulos por "Sin datos" en lugar de eliminarlos para no perder información valiosa.

df_hulu = df_hulu.fillna("Sin Datos")

# %%
print("El número total de registros en el dataset es de:",df_hulu.count().sum(),"\nEl número de registros faltantes luego del fillna() es de:",df_hulu.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 18438
# El número de registros faltantes luego del fillna() es de: 0

# %%
#Traigo los valores faltantes por columna luego del fillna()
df_hulu.isnull().sum()
# Out:
# type            0
# title           0
# cast            0
# release_year    0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Verifico no tener duplicados en mi columna Titles, ya que es la única que me interesa que no posea valores repetidos.
#(Un director puede estar en más de una película/serie, las categorías de 2 o más películas/series puede coincidir así como el cast, duración etc...)

#df_hulu.title.nunique()

print("El número de títulos individuales que se encuentran en el dataset de Hulu es de:",df_hulu.title.nunique())
# Out:
# El número de títulos individuales que se encuentran en el dataset de Hulu es de: 3073

# %%
#Utilizamos el siguiente método en cada una de las columnas para verificar la presencia de datos anómalos como carácteres especiales, espacios vacíos, números, etc.
#df_hulu.sort_values(by=["columna_a_analizar"],ascending=True).head(20)

#Luego de correr el código sobre cada columna, no encontramos valores anómalos.

# %% [markdown]
# Empiezo la limpieza de mi dataset "df_netflix".

# %%
df_netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             None
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             None
# 4      s5  TV Show           Kota Factory             None
#
#                                                 cast        country  \
# 0                                               None  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           None
# 3                                               None           None
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
#Elimino las columnas que no me servirán para las consultas indicadas.

df_netflix = df_netflix.drop(columns=["show_id","director","country","date_added","rating","description"])

# %%
#df_netflix.count().sum()
#df_netflix.isnull().sum().sum()

print("El número total de registros en el dataset es de:",df_netflix.count().sum(),"\nEl número de registros faltantes es de:",df_netflix.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 52014
# El número de registros faltantes es de: 828

# %%
#Traigo los valores faltantes por columna
df_netflix.isnull().sum()
# Out:
# type              0
# title             0
# cast            825
# release_year      0
# duration          3
# listed_in         0
# dtype: int64

# %%
#Reemplazo mis valores nulos por "Sin datos" en lugar de eliminarlos para no perder información valiosa.

df_netflix = df_netflix.fillna("Sin Datos")

# %%
print("El número total de registros en el dataset es de:",df_netflix.count().sum(),"\nEl número de registros faltantes luego del fillna() es de:",df_netflix.isnull().sum().sum())
# Out:
# El número total de registros en el dataset es de: 52842
# El número de registros faltantes luego del fillna() es de: 0

# %%
#Traigo los valores faltantes por columna luego del fillna()
df_netflix.isnull().sum()
# Out:
# type            0
# title           0
# cast            0
# release_year    0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Verifico no tener duplicados en mi columna Titles, ya que es la única que me interesa que no posea valores repetidos.
#(Un director puede estar en más de una película/serie, las categorías de 2 o más películas/series puede coincidir así como el cast, duración etc...)

#df_netflix.title.nunique()

print("El número de títulos individuales que se encuentran en el dataset de Netflix es de:",df_netflix.title.nunique())
# Out:
# El número de títulos individuales que se encuentran en el dataset de Netflix es de: 8807

# %%
#Utilizamos el siguiente método en cada una de las columnas para verificar la presencia de datos anómalos como carácteres especiales, espacios vacíos, números, etc.
#df_netflix.sort_values(by=["columna_a_analizar"],ascending=True).head(20)

#Luego de correr el código sobre cada columna, no encontramos valores anómalos.

# %% [markdown]
# <h3>Concatenamos las 4 tablas en un dataframe.<h3>

# %%
#Comenzamos por ver el número de filas de cada tabla para darnos una idea de cómo puede quedar el dataframe concatenado.

print("Número de filas por tabla","\nAmazon: ",df_amazon.shape[0])
print("Disney: ",df_disney.shape[0])
print("Hulu:   ",df_hulu.shape[0])
print("Netflix:",df_netflix.shape[0])
# Out:
# Número de filas por tabla
# Amazon:  9668
# Disney:  1450
# Hulu:    3073
# Netflix: 8807

# %%
#Insertamos una columna "platform" a cada una de las tablas para saber a qué plataforma refiere la fila.

df_amazon = df_amazon.assign(platform="amazon")
df_disney = df_disney.assign(platform="disney")
df_hulu = df_hulu.assign(platform="hulu")
df_netflix = df_netflix.assign(platform="netflix")

# %%
df_amazon.head()
# Out:
#     type                 title  \
# 0  Movie   The Grand Seduction
# 1  Movie  Take Care Good Night
# 2  Movie  Secrets of Deception
# 3  Movie    Pink: Staying True
# 4  Movie         Monster Maker
#
#                                                 cast  release_year duration  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014  113 min
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018  110 min
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017   74 min
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014   69 min
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989   45 min
#
#                  listed_in platform
# 0            Comedy, Drama   amazon
# 1     Drama, International   amazon
# 2  Action, Drama, Suspense   amazon
# 3              Documentary   amazon
# 4           Drama, Fantasy   amazon

# %%
#Concatenamos verticalmente las 4 tablas en un solo dataframe "df_final" y utilizamos ignore_index para resetear los índices.

df_final = pd.concat([df_amazon,df_disney,df_hulu,df_netflix], ignore_index=True)
df_final.shape
# Out:
# (22998, 7)

# %%
#Traemos una sample del df_final para verificar que se haya concatenado de manera correcta.

df_final.head()
# Out:
#     type                 title  \
# 0  Movie   The Grand Seduction
# 1  Movie  Take Care Good Night
# 2  Movie  Secrets of Deception
# 3  Movie    Pink: Staying True
# 4  Movie         Monster Maker
#
#                                                 cast  release_year duration  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014  113 min
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018  110 min
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017   74 min
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014   69 min
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989   45 min
#
#                  listed_in platform
# 0            Comedy, Drama   amazon
# 1     Drama, International   amazon
# 2  Action, Drama, Suspense   amazon
# 3              Documentary   amazon
# 4           Drama, Fantasy   amazon

# %%
# Separo mi columna 'duration' en 'duration_int' y 'duration_type'

def sep_duration(df):

    df = df.join(df.duration.str.split(expand=True))

    df.rename(columns={0:'duration_int',
                                1:'duration_type'}, inplace=True)
    return df

# %%
df_final = sep_duration(df_final)

# %%
df_final.head()
# Out:
#     type                 title  \
# 0  Movie   The Grand Seduction
# 1  Movie  Take Care Good Night
# 2  Movie  Secrets of Deception
# 3  Movie    Pink: Staying True
# 4  Movie         Monster Maker
#
#                                                 cast  release_year duration  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          2014  113 min
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          2018  110 min
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...          2017   74 min
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...          2014   69 min
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...          1989   45 min
#
#                  listed_in platform duration_int duration_type
# 0            Comedy, Drama   amazon          113           min
# 1     Drama, International   amazon          110           min
# 2  Action, Drama, Suspense   amazon           74           min
# 3              Documentary   amazon           69           min
# 4           Drama, Fantasy   amazon           45           min

# %%
# Separo mi columna 'duration' según valor y tipo

df_final.duration_int = df_final.duration_int.replace('Sin',0)
df_final.duration_type = df_final.duration_type.replace('Dato','Sin Dato')

# %%
df_final.duration_int = df_final.duration_int.astype('int64')

# %%
# Normalizo mi columna duration_type convirtiendo 'Season' a 'season' para que mantenga la coherencia con 'min' que se encuentra en minúscula

df_final.duration_type = df_final.duration_type.replace('Season','season')
df_final.duration_type = df_final.duration_type.replace('Seasons','season')

# %% [markdown]
# <h3>Comenzamos con la creación de funciones para realizar las consultas.<h3>

# %% [markdown]
# Función get_max_duration.

# %%
df_final.duration_int.dtype
# Out:
# dtype('int64')

# %%
def get_max_duration(anio,plataforma,tipo):
    #Convierto anio en int en caso de recibirlo como una string
    anio = int(anio)
    #Creo mis tuplas con mis posibles opciones para verificar que el input se encuentre dentro de las mismas.
    tuple_plataformas = ("amazon","disney","hulu","netflix")
    tuple_tipo = ("min","season")
    #Doy las condiciones que deben ser cumplidas para entrar al análisis, de no ser así, pido que se verifiquen los datos ingresados.
    if (anio in range(df_final.release_year.min(),df_final.release_year.max()+1)) and (plataforma in (tuple_plataformas)) and (tipo in tuple_tipo):
        #Busco el ID de la película/serie con mayor duración que se encuentre en el Dataframe que me devuelve la Query cuyo año, plataforma y tipo recibo como parámetros.
        id_final = df_final.query(f"release_year == {anio} and platform == '{plataforma}' and duration_type == '{tipo}'").duration_int.idxmax()
        #Utilizo la ID recibida para crear un diccionario con los datos del dataframe en esa ID, luego extraigo los values que me interesan informarle al usuario que realiza la consulta.
        return f'{df_final[id_final:id_final+1].to_dict().get("title").get(id_final)} Tiene la mayor duración: {df_final[id_final:id_final+1].to_dict().get("duration").get(id_final)}'
    else:
        return f"Faltan datos para su consulta o alguno de los parámetros es incorrecto, por favor verifique que los datos ingresados."

# %%
get_max_duration("2013","disney","season")
# Out:
# 'Dr. Oakley, Yukon Vet Tiene la mayor duración: 10 Seasons'

# %%
def get_count_platform(plataforma):
    #Creo mi tupla con mis posibles opciones para verificar que el input se encuentre dentro de las mismas.
    tuple_plataformas = ("amazon","disney","hulu","netflix")
    #Doy las condiciones que deben ser cumplidas para entrar al análisis, de no ser así, pido que se verifiquen los datos ingresados.
    if plataforma in (tuple_plataformas):
        #Creo un diccionario con el conteo de los títulos que se encuentran en el Dataframe que me devuelve la Query cuya plataforma recibo como parámetro, agrupado por tipo (Movie/TV Show).
        dict = df_final.query(f"platform == '{plataforma}'").groupby(by=['type']).title.count().to_dict()
        #Extraigo los values que me interesan informarme al usuario que realiza la consulta.
        return f'El conteo de la plataforma {plataforma} es: {dict.get("Movie")} películas y {dict.get("TV Show")} series'
    else:
        return f"Faltan datos para su consulta o alguno de los parámetros es incorrecto, por favor verifique que los datos ingresados."

# %%
get_count_platform("netflix")
# Out:
# 'El conteo de la plataforma netflix es: 6131 películas y 2676 series'

# %%
def get_listedin(genero):
    #Utilizo un str.contains case_sensitive=False sobre mi columna listed_in, luego agrupo por 'platform' y realizo un conteo de los títulos para convertir estos datos en un diccionario.
    #En este caso, no utilizo ningún if para dar condiciones ya que los generos en 'listed_in' no se encuentran normalizados por su gran variedad, por ejemplo, existen valores para 'Comedy' y para 'Comedies'
    conteo = df_final[df_final.listed_in.str.contains(genero, case=False)].groupby(by=['platform']).title.count().to_dict()
    #Extraigo los values que me interesan informarme al usuario que realiza la consulta.
    return f'El género {genero} aparece {conteo.get("amazon")} veces en amazon, {conteo.get("disney")} veces en disney, {conteo.get("hulu")} veces en hulu y {conteo.get("netflix")} veces en netflix'

# %%
get_listedin('comedy')
# Out:
# 'El género "comedy" aparece 2099 veces en amazon, 526 veces en disney, 667 veces en hulu y 399 veces en netflix'

# %%
def get_actor(plataforma, anio):
    #Convierto anio en int en caso de recibirlo como una string
    anio = int(anio)
    #Creo mi tupla con mis posibles opciones para verificar que el input se encuentre dentro de las mismas.
    tuple_plataformas = ("amazon","disney","hulu","netflix")
    #Doy las condiciones que deben ser cumplidas para entrar al análisis, de no ser así, pido que se verifiquen los datos ingresados.
    if (anio in range(df_final.release_year.min(),df_final.release_year.max()+1)) and (plataforma in (tuple_plataformas)):
        #Creo mi lista de actores final vacía
        actor_list = []
        #Creo una lista del cast por película/TV_Show que se encuentren en el Dataframe que me devuelve la Query cuyo año y plataforma recibo como parámetros.
        cast_list = df_final.query(f"platform == '{plataforma}' and release_year == {anio}").cast.tolist()
        #Divido los actores del Cast y los agrego a una lista temporal de actores a la que luego le excluyo los valores 'Sin Datos' para mi lista de actores final.
        for i in range(len(cast_list)):
            actor_list_temp = cast_list[i].split(",")
            for j in range(len(actor_list_temp)):
                if actor_list_temp[j] != 'Sin Datos':
                    actor_list.append(actor_list_temp[j])
        #Convierto en diccionario mi lista de actores pero únicamente con el valor del que más apariciones tiene.
        dict_actor = dict(zip(actor_list,map(lambda x: actor_list.count(x),actor_list)))
        #Consigo la Key del diccionario que corresponde al Actor/actriz con más apariciones.
        max_actor = max(dict_actor, key=dict_actor.get)
        #Consigo el Value de apariciones de dicho Actor/actriz
        max_actor_appearances = dict_actor.get(max_actor)
        #Extraigo los values que me interesan informarme al usuario que realiza la consulta.
        return f'El actor/actriz con mayor número de apariciones en la plataforma {plataforma} el año {anio} es {max_actor} con {max_actor_appearances} apariciones.'
    else:
        return f"Faltan datos para su consulta o alguno de los parámetros es incorrecto, por favor verifique que los datos ingresados."

# %%
get_actor("netflix", "2018")
# Out:
# 'El actor/actriz con mayor número de apariciones en la plataforma "netflix" el año 2018 es " Andrea Libman" con 8 apariciones.'
